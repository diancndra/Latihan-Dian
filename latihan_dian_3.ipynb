# %%
bunga = ["kamboja", "sedap malam", "mawar", "melati", "peony"]
print (bunga)
# Out:
# ['kamboja', 'sedap malam', 'mawar', 'melati', 'peony']

# %%
print (bunga[0:3])
# Out:
# ['kamboja', 'sedap malam', 'mawar']

# %%
nama = ["haechan", "johnny", "mark", "andy"]
nama.append ("joshua")
print (nama)
# Out:
# ['haechan', 'johnny', 'mark', 'andy', 'joshua']

# %%
nama.insert(2,"mingyu")
print (nama)
# Out:
# ['haechan', 'johnny', 'mingyu', 'mark', 'andy', 'joshua']

# %%
nama.remove ("andy")
print (nama)
# Out:
# ['haechan', 'johnny', 'mingyu', 'mark', 'joshua']

# %%
print ("mingyu" in nama)
print ("andy" in nama)
# Out:
# True
# False

# %%
bunga = ["kamboja", "sedap malam", "mawar", "melati", "peony"]
for jenis in bunga :
  print (jenis)
# Out:
# kamboja
# sedap malam
# mawar
# melati
# peony
